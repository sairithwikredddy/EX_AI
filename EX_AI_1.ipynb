# %% [markdown]
# <a href="https://colab.research.google.com/github/sairithwikredddy/EX_AI/blob/main/EX_AI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## problem *1*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import shap
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_excel('/content/Car_Sales.xlsx')
data
# Out:
#    Number of TV Ads (x)  Number of Cars Sold (y)
# 0                     1                       14
# 1                     3                       24
# 2                     2                       18
# 3                     1                       17
# 4                     3                       27

# %%
x=data.iloc[:,0:-1].values
y=data.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression

# %%
explainer=shap.Explainer(model.predict, x)
shap_values=explainer(x)
shap_values
# Out:
# .values =
# array([[-5.],
#        [ 5.],
#        [ 0.],
#        [-5.],
#        [ 5.]])
#
# .base_values =
# array([20., 20., 20., 20., 20.])
#
# .data =
# array([[1],
#        [3],
#        [2],
#        [1],
#        [3]])

# %%
shap.plots.waterfall(shap_values[0])
shap.plots.waterfall(shap_values[1])
shap.plots.waterfall(shap_values[2])

# %%
shap.initjs()
shap.plots.force(shap_values[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.initjs()
shap.plots.force(shap_values[1])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.initjs()
shap.plots.force(shap_values[2])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# # ***studyHour***(problem2)

# %%
data=pd.read_excel('/content/StudyHour.xlsx')
data
# Out:
#    IQ \n  StudyHours  TestScore
# 0    110          40        100
# 1    120          30         90
# 2    100          20         80
# 3     90           0         70
# 4     80          10         60

# %%
X=data.iloc[:,0:-1].values
Y=data.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression().fit(X,Y)

# %%
print('Intercept:\n',model.intercept_)
print('Coefficients:\n',model.coef_)
# Out:
# Intercept:
#  20.000000000000014
# Coefficients:
#  [0.5 0.5]

# %%
explainer = shap.Explainer(model.predict, x)
shap_values=explainer(X)
shap_values
# Out:
# .values =
# array([[  5.,  10.],
#        [ 10.,   5.],
#        [  0.,   0.],
#        [ -5., -10.],
#        [-10.,  -5.]])
#
# .base_values =
# array([80., 80., 80., 80., 80.])
#
# .data =
# array([[110,  40],
#        [120,  30],
#        [100,  20],
#        [ 90,   0],
#        [ 80,  10]])

# %%
shap.plots.waterfall(shap_values[0])
shap.plots.waterfall(shap_values[1])

# %%
shap.initjs()
shap.plots.force(shap_values[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.initjs()
shap.plots.force(shap_values[1])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# ## problem **3**

# %%
data=pd.read_csv('/content/Experience_Salary.csv')
data
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
X=data.iloc[:,0:-1].values
Y=data.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression().fit(X,Y)

# %%
print('Intercept:\n',model.intercept_)
print('Coefficients:\n',model.coef_)
# Out:
# Intercept:
#  25792.200198668696
# Coefficients:
#  [9449.96232146]

# %%
explainer = shap.Explainer(model.predict, X)
shap_values=explainer(X)
shap_values
# Out:
# .values =
# array([[-39815.84124773],
#        [-37925.84878344],
#        [-36035.85631915],
#        [-31310.87515842],
#        [-29420.88269413],
#        [-22805.90906911],
#        [-21860.91283697],
#        [-19970.92037268],
#        [-19970.92037268],
#        [-15245.93921195],
#        [-13355.94674766],
#        [-12410.95051551],
#        [-12410.95051551],
#        [-11465.95428337],
#        [ -7685.96935478],
#        [ -3905.9844262 ],
#        [ -2015.99196191],
#        [  -125.99949762],
#        [  5543.97789525],
#        [  6488.9741274 ],
#        [ 14048.94398456],
#        [ 16883.932681  ],
#        [ 24443.90253816],
#        [ 27278.8912346 ],
#        [ 32003.87239533],
#        [ 34838.86109176],
#        [ 39563.84225249],
#        [ 40508.83848464],
#        [ 47123.81210966],
#        [ 49013.80457395]])
#
# .base_values =
# array([76003., 76003., 76003., 76003., 76003., 76003., 76003., 76003.,
# ...

# %%
shap.plots.waterfall(shap_values[0])
shap.plots.waterfall(shap_values[1])
shap.plots.waterfall(shap_values[2])
